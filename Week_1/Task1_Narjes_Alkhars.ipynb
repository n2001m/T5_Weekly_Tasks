# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('Task (1) Dataset.csv')

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 12311   Lorry (11?40Q)            Owner                     NaN  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %%
df.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
print(df['Fitness_of_casuality'].unique())#
print()
print(df['Work_of_casuality'].unique())#
print()
print(df['Vehicle_movement'].unique())#
print()
print(df['Type_of_collision'].unique())#
print()
print(df['Road_surface_type'].unique())#
print()
print(df['Educational_level'].unique())#
print()
print(df['Vehicle_driver_relation'].unique())#
print()
print(df['Defect_of_vehicle'].unique())#change
print()
print(df['Area_accident_occured'].unique())#
print()
print(df['Lanes_or_Medians'].unique())#
print()
print(df['Road_allignment'].unique())#
print()
print(df['Types_of_Junction'].unique())#
print()
print(df['Driving_experience'].unique())#
print()
print(df['Type_of_vehicle'].unique())#
print()
print(df['Owner_of_vehicle'].unique())#
print()
print(df['Service_year_of_vehicle'].unique())#
print()
# Out:
# [nan 'Normal' 'Deaf' 'Other' 'Blind' 'NormalNormal']
#
# [nan 'Driver' 'Other' 'Unemployed' 'Employee' 'Self-employed' 'Student'
#  'Unknown']
#
# ['Going straight' 'U-Turn' 'Moving Backward' 'Turnover' 'Waiting to go'
#  'Getting off' 'Reversing' 'Unknown' 'Parked' 'Stopping' 'Overtaking'
#  'Other' 'Entering a junction' nan]
#
# ['Collision with roadside-parked vehicles'
#  'Vehicle with vehicle collision' 'Collision with roadside objects'
#  'Collision with animals' 'Other' 'Rollover' 'Fall from vehicles'
#  'Collision with pedestrians' 'With Train' 'Unknown' nan]
#
# ['Asphalt roads' 'Earth roads' nan 'Asphalt roads with some distress'
#  'Gravel roads' 'Other']
#
# ['Above high school' 'Junior high school' nan 'Elementary school'
#  'High school' 'Unknown' 'Illiterate' 'Writing & reading']
#
# ['Employee' 'Unknown' 'Owner' nan 'Other']
#
# ['No defect' nan '7' '5']
#
# ['Residential areas' 'Office areas' '  Recreational areas'
# ...

# %%
df = df.drop(columns=['Fitness_of_casuality', 'Work_of_casuality', 'Educational_level', 'Vehicle_driver_relation', 'Type_of_vehicle', 'Service_year_of_vehicle'], axis = 1)

# %%
df['Vehicle_movement'].fillna('Unknown', inplace=True)
df['Type_of_collision'].fillna('Unknown', inplace=True)
df['Road_surface_type'].fillna('Other', inplace=True)
df['Area_accident_occured'].fillna('Other', inplace=True)
df['Lanes_or_Medians'].fillna('Unknown', inplace=True)
df['Types_of_Junction'].fillna('Unknown', inplace=True)
df['Driving_experience'].fillna('unknown', inplace=True)
df['Owner_of_vehicle'].fillna('Other', inplace=True)

# %%
df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode()[0], inplace=True)
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Driving_experience           12316 non-null  object
#  5   Owner_of_vehicle             12316 non-null  object
#  6   Defect_of_vehicle            12316 non-null  object
#  7   Area_accident_occured        12316 non-null  object
#  8   Lanes_or_Medians             12316 non-null  object
#  9   Road_allignment              12316 non-null  object
#  10  Types_of_Junction            12316 non-null  object
#  11  Road_surface_type            12316 non-null  object
#  12  Road_surface_conditions      12316 non-null  object
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %% [markdown]
# Time                              0
#
# Day_of_week                       0
#
# Age_band_of_driver                0
#
# Sex_of_driver                     0
#
# Road_surface_conditions           0
#
# Light_conditions                  0
#
# Weather_conditions                0
#
# Number_of_vehicles_involved       0
#
# Number_of_casualties              0
#
# Casualty_class                    0
#
# Sex_of_casualty                   0
#
# Age_band_of_casualty              0
#
# Casualty_severity                 0
#
# Pedestrian_movement               0
#
# Cause_of_accident                 0
#
# Accident_severity                 0

# %%
print(df['Time'].unique())
print('Time')
print(df['Day_of_week'].unique())
print('Day_of_week')
print(df['Age_band_of_driver'].unique())
print('Age_band_of_driver')
print(df['Sex_of_driver'].unique())
print('Sex_of_driver')
print(df['Road_surface_conditions'].unique())
print('Road_surface_conditions')
print(df['Light_conditions'].unique())
print('Light_conditions')
print(df['Weather_conditions'].unique())
print('Weather_conditions')
print(df['Defect_of_vehicle'].unique())#change
print('Defect_of_vehicle')
print(df['Number_of_vehicles_involved'].unique())
print('Number_of_vehicles_involved')
print(df['Number_of_casualties'].unique())
print('Number_of_casualties')
print(df['Casualty_class'].unique())
print('Casualty_class')
print(df['Sex_of_casualty'].unique())
print('Sex_of_casualty')
print(df['Age_band_of_casualty'].unique())
print('Age_band_of_casualty')
print(df['Casualty_severity'].unique())
print('Casualty_severity')
print(df['Pedestrian_movement'].unique())
print('Pedestrian_movement')
print(df['Cause_of_accident'].unique())
print('Cause_of_accident')
print(df['Accident_severity'].unique())
print('Accident_severity')
# Out:
# ['17:02:00' '1:06:00' '14:15:00' ... '7:24:00' '19:18:00' '2:47:00']
# Time
# ['Monday' 'Sunday' 'Friday' 'Wednesday' 'Saturday' 'Thursday' 'Tuesday']
# Day_of_week
# ['18-30' '31-50' 'Under 18' 'Over 51' 'Unknown']
# Age_band_of_driver
# ['Male' 'Female' 'Unknown']
# Sex_of_driver
# ['Dry' 'Wet or damp' 'Snow' 'Flood over 3cm. deep']
# Road_surface_conditions
# ['Daylight' 'Darkness - lights lit' 'Darkness - no lighting'
#  'Darkness - lights unlit']
# Light_conditions
# ['Normal' 'Raining' 'Raining and Windy' 'Cloudy' 'Other' 'Windy' 'Snow'
#  'Unknown' 'Fog or mist']
# Weather_conditions
# ['No defect' '7' '5']
# Defect_of_vehicle
# [2 1 3 6 4 7]
# Number_of_vehicles_involved
# [2 1 3 4 6 5 8 7]
# Number_of_casualties
# ['na' 'Driver or rider' 'Pedestrian' 'Passenger']
# Casualty_class
# ['na' 'Male' 'Female']
# Sex_of_casualty
# ['na' '31-50' '18-30' 'Under 18' 'Over 51' '5']
# Age_band_of_casualty
# ['na' '3' '2' '1']
# Casualty_severity
# ...

# %%
Accident_severity_mapping = {'Slight Injury': 1, 'Serious Injury': 2, 'Fatal injury': 3}
df['Accident_severity'] = df['Accident_severity'].map(Accident_severity_mapping)

# %%
Defect_of_vehicle_mapping = {'No defect': 0, '7': 7, '5': 5}
df['Defect_of_vehicle'] = df['Defect_of_vehicle'].map(Defect_of_vehicle_mapping)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Casualty_severity_Encoder = LabelEncoder()
df['Casualty_severity'] = Casualty_severity_Encoder.fit_transform(df['Casualty_severity'])

# %%
Age_band_of_driver_enc = {'Under 18': 1, '18-30': 2, '31-50': 3, 'Over 51': 4, 'Unknown': 0}
df['Age_band_of_driver_en'] = df['Age_band_of_driver'].map(Age_band_of_driver_enc)
df['Age_band_of_driver_en']
# Out:
# 0        2
# 1        3
# 2        2
# 3        2
# 4        2
#         ..
# 12311    3
# 12312    0
# 12313    4
# 12314    2
# 12315    2
# Name: Age_band_of_driver_en, Length: 12316, dtype: int64

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#        Defect_of_vehicle  Number_of_vehicles_involved  Number_of_casualties  \
# count       12316.000000                 12316.000000          12316.000000
# mean            0.057811                     2.040679              1.548149
# std             0.610028                     0.688790              1.007179
# min             0.000000                     1.000000              1.000000
# 25%             0.000000                     2.000000              1.000000
# 50%             0.000000                     2.000000              1.000000
# 75%             0.000000                     2.000000              2.000000
# max             7.000000                     7.000000              8.000000
#
#        Casualty_severity  Accident_severity  Age_band_of_driver_en
# count       12316.000000       12316.000000           12316.000000
# mean            2.293927           1.167181               2.270867
# std             0.587734           0.406082               1.158926
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
bar_col= ['Accident_severity', 'Cause_of_accident', 'Casualty_class', 'Number_of_casualties', 'Number_of_vehicles_involved', 'Defect_of_vehicle', 'Weather_conditions', 'Road_surface_conditions','Casualty_severity', 'Accident_severity']
for column in bar_col:
    plt.figure(figsize=(10, 6))
    df[column].value_counts().sort_index().plot(kind='bar')
    plt.show()

# %%
sns.pairplot(df)

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
Age_band_of_driver_pie = df['Age_band_of_driver'].value_counts()
plt.pie(Age_band_of_driver_pie, labels=Age_band_of_driver_pie.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x78dc76e708b0>,
# ...
#  [Text(0.5092641845009233, 0.9750128154976271, '18-30'),
#   Text(-1.0964958595541783, -0.08773157915223044, '31-50'),
#   Text(-0.048526358840080504, -1.0989291116799682, 'Over 51'),
#   Text(0.7538523285207841, -0.8010659565752323, 'Unknown'),
#   Text(1.0757323689809388, -0.2297822236959542, 'Under 18')])

# %%
Sex_of_casualty_pie = df['Sex_of_casualty'].value_counts()
plt.pie(Sex_of_casualty_pie, labels=Sex_of_casualty_pie.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x78dc76e9ff10>,
# ...
#  [Text(0.25168493059987573, 1.0708196373381167, 'Male'),
#   Text(-0.8610882043028047, -0.6844903976028965, 'na'),
#   Text(0.8633533812393457, -0.6816310872477789, 'Female')])

# %%
Age_band_of_casualty_pie = df['Age_band_of_casualty'].value_counts()
plt.pie(Age_band_of_casualty_pie, labels=Age_band_of_casualty_pie.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x78dc76ef6800>,
# ...
#  [Text(0.46600997192232485, 0.9964109122590711, 'na'),
#   Text(-1.0970945009855888, 0.07989778411934768, '18-30'),
#   Text(-0.23471898744636918, -1.074665993196096, '31-50'),
#   Text(0.6875611289871651, -0.8586382788496533, 'Under 18'),
#   Text(1.0223321818495674, -0.4060011206323242, 'Over 51'),
#   Text(1.0978700887032171, -0.06841979487538782, '5')])

# %%
Light_conditions_pie = df['Light_conditions'].value_counts()
plt.pie(Light_conditions_pie, labels=Light_conditions_pie.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x78dc76d4e5c0>,
# ...
#  [Text(-0.6860267462403117, 0.8598647006610581, 'Daylight'),
#   Text(0.633969455439531, -0.8989342187110827, 'Darkness - lights lit'),
#   Text(1.0973534015049724, -0.07625950567284771, 'Darkness - no lighting'),
#   Text(1.0999427403413138, -0.011223545359701168, 'Darkness - lights unlit')])

# %%
Sex_of_driver_pie = df['Sex_of_driver'].value_counts()
plt.pie(Sex_of_driver_pie, labels=Sex_of_driver_pie.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x78dc76da9600>,
# ...
#  [Text(-1.072465263047081, 0.24457771680460846, 'Male'),
#   Text(1.0602587952163456, -0.2930039029883113, 'Female'),
#   Text(1.0988663171073576, -0.04992811960120703, 'Unknown')])

# %%
Defect_of_vehicle_pie = df['Defect_of_vehicle'].value_counts()
plt.pie(Defect_of_vehicle_pie, labels=Defect_of_vehicle_pie.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x78dc76e00370>,
# ...
#  [Text(-1.099551118821503, 0.03142192066664789, '0'),
#   Text(1.0992162137186747, -0.04151765284768306, '7'),
#   Text(1.0999536194152948, -0.010101244239844473, '5')])

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.plot.hexbin(x= 'Age_band_of_driver_en' , y='Accident_severity' , gridsize = 15 )
# Out:
# <Axes: xlabel='Age_band_of_driver_en', ylabel='Accident_severity'>

# %%
sns.scatterplot(data=df, y='Accident_severity', x='Age_band_of_driver_en')
# Out:
# <Axes: xlabel='Age_band_of_driver_en', ylabel='Accident_severity'>

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
df.boxplot(figsize=(12,10))
# Out:
# <Axes: >

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
df = remove_outliers(df, 'Defect_of_vehicle')
df = remove_outliers(df, 'Number_of_vehicles_involved')
df = remove_outliers(df, 'Number_of_casualties')
df = remove_outliers(df, 'Casualty_severity')
df = remove_outliers(df, 'Accident_severity')

# %%
df.boxplot(figsize=(12,8))
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
df.hist(figsize=(15,12))
# Out:
# array([[<Axes: title={'center': 'Defect_of_vehicle'}>,
#         <Axes: title={'center': 'Number_of_vehicles_involved'}>],
#        [<Axes: title={'center': 'Number_of_casualties'}>,
#         <Axes: title={'center': 'Casualty_severity'}>],
#        [<Axes: title={'center': 'Accident_severity'}>,
#         <Axes: title={'center': 'Age_band_of_driver_en'}>]], dtype=object)

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %%
#there is a pattern in the accidents as shown in the pairplot the data is clustered or shaped in lines so the relationship between the columns is not strong, their was outliers but i got rid of them
